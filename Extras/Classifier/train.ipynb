# %%
import basic_function as bf
from model import Model

# from keras.models import Sequential
# from keras.layers import Conv2D, MaxPooling2D
# from keras.layers import Activation, Dropout, Flatten, Dense
# from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
dataset_path = '../../Dataset/preview/set3/'

# %%
def train(test_file,validation_file,weight_file = None, model = None):
    if model is None:
        model = Model()
        model.init_model()

    model.train(test_file,validation_file)
    
    if weight_file is not None:
        model.save_weights(weight_file)
            
    return model

# %%
model = train(dataset_path + 'test', dataset_path + 'validation', 'weights/set3_1.h5')
# Out:
# Model Information :
# Data Size : (300, 300)
# Epochs : 50
# Model is not Initialize yet.
# Initializing Model...
# Compiling Model...
# ...
# Found 2370 images belonging to 2 classes.
# Found 591 images belonging to 2 classes.
# Training...
# Epoch 1/50
# 25/25 [==============================] - 42s 2s/step - loss: 1.2366 - acc: 0.6100 - val_loss: 0.6744 - val_acc: 0.8750
# Epoch 2/50
# 25/25 [==============================] - 40s 2s/step - loss: 0.4740 - acc: 0.8050 - val_loss: 0.4436 - val_acc: 0.7688
# Epoch 3/50
# 25/25 [==============================] - 40s 2s/step - loss: 0.4567 - acc: 0.8475 - val_loss: 0.1815 - val_acc: 0.9563
# Epoch 4/50
# 25/25 [==============================] - 45s 2s/step - loss: 0.4461 - acc: 0.9050 - val_loss: 0.1581 - val_acc: 0.9245
# Epoch 5/50
# 25/25 [==============================] - 40s 2s/step - loss: 0.3255 - acc: 0.8950 - val_loss: 0.2236 - val_acc: 0.9500
# Epoch 6/50
# ...
